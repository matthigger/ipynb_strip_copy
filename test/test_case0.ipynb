# %%
# this should stick around

# %% [markdown]
# # this should stick around

# %% [markdown]
# # This markdown cell should be unaffected

# %%
# This code cell should be unaffected
